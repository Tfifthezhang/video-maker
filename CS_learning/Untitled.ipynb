# %%
! manim -qh enumerate/enumerate.py handshake
# Out:
# Manim Community v0.15.1
#
# [12/14/22 08:51:57] INFO     Animation 0 : Using cached     ]8;id=113364;file:///usr/local/lib/python3.8/site-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=789748;file:///usr/local/lib/python3.8/site-packages/manim/renderer/cairo_renderer.py#75\75]8;;\
#                              data (hash : 450974505_1874713
#                              150_3466495711)
# [12/14/22 08:51:59] INFO     Animation 1 : Partial      ]8;id=452694;file:///usr/local/lib/python3.8/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=868043;file:///usr/local/lib/python3.8/site-packages/manim/scene/scene_file_writer.py#500\500]8;;\
#                              movie file written in '/ma
#                              nim/CS_learning/media/vide
#                              os/enumerate/1080p60/parti
#                              al_movie_files/handshake/3
#                              4786186_3615899359_2236995
# ...

# %%
from manim import *
def add_code(code_path, language):
    listing = Code(
        code_path,
        tab_width=4,
        background_stroke_width=1,
        background_stroke_color=WHITE,
        line_spacing=3,
        insert_line_no=True,
        style=Code.styles_list[15],
        background="window",
        language=language,
    )
    return listing
code = add_code('enumerate/code1.py', 'python')
# Out:
# Manim Community v0.15.1

# %%
code.code[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 code.code[4]
#
# File /usr/local/lib/python3.8/site-packages/manim/mobject/mobject.py:2089, in Mobject.__getitem__(self, value)
#    2087     GroupClass = self.get_group_class()
#    2088     return GroupClass(*self_list.__getitem__(value))
# -> 2089 return self_list.__getitem__(value)
#
# IndexError: list index out of range

# %%
from manim import *
Tex('$\\frac{res}{2}$')
# Out:
# [12/14/22 07:52:25] INFO     Writing $\frac{res}{2}$ to                ]8;id=949322;file:///usr/local/lib/python3.8/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=152339;file:///usr/local/lib/python3.8/site-packages/manim/utils/tex_file_writing.py#87\87]8;;\
#                              media/Tex/326ccffeb8a98fb1.tex
# Tex('$\\frac{res}{2}$')
