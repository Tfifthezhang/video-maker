# %%
# !manim -qh algoritms_analysis.py BubbleSort
# Out:
# Manim Community v0.15.2
#
# [04/29/22 07:51:12] INFO     Animation 0 : Using cached     ]8;id=765800;file:///usr/local/lib/python3.8/site-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=752160;file:///usr/local/lib/python3.8/site-packages/manim/renderer/cairo_renderer.py#75\75]8;;\
#                              data (hash :
#                              450974505_17736648_1906491166)
#                     INFO     Animation 1 : Using cached     ]8;id=45891;file:///usr/local/lib/python3.8/site-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=926498;file:///usr/local/lib/python3.8/site-packages/manim/renderer/cairo_renderer.py#75\75]8;;\
#                              data (hash : 34786186_16822656
#                              40_2367128670)
# ...
