# %% [markdown]
# # 文字、公式、图片
#
#
# ## 插入SVG
#
# svg = SVGMobject('coin.svg',color = BLUE,stroke_width = 5.00)
# self.play(Uncreate(svg))
#
# ## 插入文字（本质上是转化为svg）
# text = Text('Hello, world!'，color = BLUE，t2c={'llo':RED})
# self.play(Write(text))
# ### 或者
# text = TextMobject('Text文字',color=BLUE,background_stroke_color=RED)
# self.play(Uncreate(text))
# ###### 存在索引，‘ab’就是在text2【0】，a就是text2[0][0]
# text2 = TextMobject('ab','cde')
#
# ## 插入图片
# img = ImageMobject('up.png',height =3,invert = False)
# self.play(FadeOut(img))
#
# ## 插入文字或者公式
# text = TexMobject('\\sum^n_{i=1}i^3=?')
#
# TextMobject('文字$公式$') == TexMobject('\\text{文字}公式')
#
# text2 =MathTex("\\frac{d}{dx}f(x)g(x)=","f(x)\\frac{d}{dx}g(x)","+",
#             "g(x)\\frac{d}{dx}f(x)")
#
#
#
# # 数学几何
#
# ## 直线
# import numpy as np
# line = Line(start=np.array([-4,-3,0]),end = np.array([0,3,0]),buff=0.0,stroke_width = 1)
#
# ### 使用下面可以两点确定一个函数
# line.put_start_and_end_on(start = np.array([-4,-3,0]),end = np.array([0,3,0]))
# line.scale(2)
#
# ## 类似的类有向量，虚线，箭头，双箭头，圆弧
# vector = Vector(UP*2+LEFT*3),vector.shift(UP*2+LEFT*3) # 默认起点为原点
# DashedLine，
# Arrow(tip_length=0.35) #箭头大小
# DoubleArrow
# Arc
# TangentLine
#
# # VGoup
# vgroup = VGroup(...) # 跟python的列表一样，添加，删除，遍历
# vgroup.add(mob3)
# vgroup.add_to_back(mob)
#
# ## 支持移动
# vgroup = VGroup(a,b,c)
# vgroup.shift(UP)
# vg[0].shift(DOWN*2)
# a.shift(DOWN)
#
# ## 可以嵌套使用,只能存放VMobject
# vg1 = VGroup(a,b,c)
# vg2 = Vgroup(d,e)
# VG = VGroup(vg1,vg2)
